# %%
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))
import jupyter_helper
from keras.backend import clear_session
import pandas as pd
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
report={}
# report['window']=[]
report['acc']=[]
report['time']=[]
window=2
days=1

# %%
for i in range(1,31):
    h = jupyter_helper.do(
        window=window,
        days=days,
        wrapper=jupyter_helper.wrapper(),
        norm=jupyter_helper.normalize(),
        summary=False)
    s=jupyter_helper.show_history(h,print_score=False,show_plt=False)
    clear_session()
#     report['window'].append(i)
    report['acc'].append(s['score'][2])
    report['time'].append(h['end']-h['start'])
# Out:
# Net time using :  59.43507432937622  secs.
# 520/520 [==============================] - ETA:  - 0s 83us/step
# Slope Day1:1.0346219865411899
# Net time using :  59.87309718132019  secs.
# 520/520 [==============================] - ETA:  - 0s 89us/step
# Slope Day1:1.0426404766784607
# Net time using :  74.38599228858948  secs.
# 520/520 [==============================] - ETA:  - 0s 89us/step
# Slope Day1:1.0120639531010787
# Net time using :  71.10859680175781  secs.
# 520/520 [==============================] - ETA:  - 0s 89us/step
# Slope Day1:1.0207686567031773
# Net time using :  80.12080550193787  secs.
# 520/520 [==============================] - ETA:  - 0s 87us/step
# Slope Day1:1.0177953183601012
# Net time using :  39.11106491088867  secs.
# 520/520 [==============================] - ETA:  - 0s 85us/step
# Slope Day1:1.0620281380430796
# Net time using :  55.34754753112793  secs.
# 520/520 [==============================] - ETA:  - 0s 89us/step
# Slope Day1:1.0399627343222193
# Net time using :  61.1211302280426  secs.
# 520/520 [==============================] - ETA:  - 0s 89us/step
# Slope Day1:1.0467159283045864
# Net time using :  59.2090744972229  secs.
# 520/520 [==============================] - ETA:  - 0s 92us/step
# Slope Day1:1.0445573873672493
# Net time using :  76.88748407363892  secs.
# 520/520 [==============================] - ETA:  - 0s 85us/step
# Slope Day1:1.0156746317943954
# Net time using :  66.6665632724762  secs.
# 520/520 [==============================] - ETA:  - 0s 96us/step
# Slope Day1:1.042818875527836
# Net time using :  94.05095076560974  secs.
# 520/520 [==============================] - ETA:  - 0s 87us/step
# Slope Day1:1.0193175842778195
# Net time using :  82.57055401802063  secs.
# 520/520 [==============================] - ETA:  - 0s 83us/step
# Slope Day1:1.0407360025687828
# Net time using :  63.77470326423645  secs.
# 520/520 [==============================] - ETA:  - 0s 102us/step
# Slope Day1:1.0277009743650574
# Net time using :  24.962321281433105  secs.
# 520/520 [==============================] - ETA:  - ETA:  - 0s 135us/step
# Slope Day1:2.134994888163729
# Net time using :  65.58824920654297  secs.
# 520/520 [==============================] - ETA:  - 0s 87us/step
# Slope Day1:1.0309527216575334
# Net time using :  64.44242000579834  secs.
# 520/520 [==============================] - ETA:  - 0s 83us/step
# Slope Day1:1.0428942155095233
# Net time using :  113.36312913894653  secs.
# 520/520 [==============================] - ETA:  - 0s 90us/step
# Slope Day1:0.996569474559598
# Net time using :  93.91255140304565  secs.
# 520/520 [==============================] - ETA:  - 0s 85us/step
# Slope Day1:1.0044263277316752
# Net time using :  51.80468678474426  secs.
# 520/520 [==============================] - ETA:  - 0s 100us/step
# Slope Day1:1.046116941724215
# Net time using :  110.49884366989136  secs.
# 520/520 [==============================] - ETA:  - 0s 90us/step
# Slope Day1:1.0076950857833344
# Net time using :  56.641918659210205  secs.
# 520/520 [==============================] - ETA:  - 0s 89us/step
# Slope Day1:1.0313028685506618
# Net time using :  19.62683415412903  secs.
# 520/520 [==============================] - ETA:  - 0s 90us/step
# Slope Day1:2.1746749285647753
# Net time using :  60.5002863407135  secs.
# 520/520 [==============================] - ETA:  - 0s 83us/step
# Slope Day1:1.039298061577166
# Net time using :  68.00494432449341  secs.
# 520/520 [==============================] - ETA:  - 0s 89us/step
# Slope Day1:1.012814690567799
# Net time using :  104.37380528450012  secs.
# 520/520 [==============================] - ETA:  - 0s 90us/step
# Slope Day1:1.0137532040171944
# Net time using :  60.60201692581177  secs.
# 520/520 [==============================] - ETA:  - 0s 89us/step
# Slope Day1:1.0275546091266847
# Net time using :  60.61763906478882  secs.
# 520/520 [==============================] - ETA:  - 0s 85us/step
# Slope Day1:1.037130603912298
# Net time using :  60.08126783370972  secs.
# 520/520 [==============================] - ETA:  - 0s 83us/step
# Slope Day1:1.03405246002132
# Net time using :  11.538531303405762  secs.
# 520/520 [==============================] - ETA:  - 0s 87us/step
# Slope Day1:2.0916075881551994

# %% [markdown]
# ### 报告

# %%
pd.DataFrame(report).describe()
# Out:
#                 acc        time
# count  3.000000e+01   30.000000
# mean   9.615385e-03   65.674069
# std    1.764379e-18   23.605829
# min    9.615385e-03   11.538531
# 25%    9.615385e-03   59.265574
# 50%    9.615385e-03   62.447917
# 75%    9.615385e-03   76.262111
# max    9.615385e-03  113.363129
