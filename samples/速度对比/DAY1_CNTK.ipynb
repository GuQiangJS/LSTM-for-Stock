# %%
import os
os.environ['KERAS_BACKEND']='cntk'
import sys
sys.path.append(os.path.dirname(os.getcwd()))
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))
import jupyter_helper
from keras.backend import clear_session
import pandas as pd
import numpy as np
# Out:
# Using CNTK backend
# C:\Users\guqiang\AppData\Local\conda\conda\envs\finance35\lib\site-packages\cntk\cntk_py_init.py:32: UserWarning: Unsupported Windows version (2012serverr2). CNTK supports Windows 10 and above, only.
#   warnings.warn('Unsupported Windows version (%s). CNTK supports Windows 10 and above, only.' % __my_distro_ver__)
# C:\Users\guqiang\AppData\Local\conda\conda\envs\finance35\lib\site-packages\cntk\cntk_py_init.py:84: UserWarning:
#
# ################################################ Missing optional dependency (GPU-Specific) ################################################
#    CNTK may crash if the component that depends on those dependencies is loaded.
#    Visit https://docs.microsoft.com/en-us/cognitive-toolkit/Setup-Windows-Python#optional-gpu-specific-packages for more information.
# ############################################################################################################################################
# If you intend to use CNTK without GPU support, you can ignore the (likely) GPU-specific warning!
# ############################################################################################################################################
#
#   warnings.warn(WARNING_MSG_GPU_ONLY % ('GPU-Specific', 'https://docs.microsoft.com/en-us/cognitive-toolkit/Setup-Windows-Python#optional-gpu-specific-packages'))
# C:\Users\guqiang\AppData\Local\conda\conda\envs\finance35\lib\site-packages\keras\backend\cntk_backend.py:26: UserWarning: CNTK backend warning: GPU is not detected. CNTK's CPU version is not fully optimized,please run with GPU to get better performance.
#   'CNTK backend warning: GPU is not detected. '

# %%
report={}
# report['window']=[]
report['acc']=[]
report['time']=[]
window=2
days=1

# %%
for i in range(1,31):
    h = jupyter_helper.do(
        window=window,
        days=days,
        wrapper=jupyter_helper.wrapper(),
        norm=jupyter_helper.normalize(),
        summary=False)
    s=jupyter_helper.show_history(h,print_score=False,show_plt=False)
    clear_session()
#     report['window'].append(i)
    report['acc'].append(s['score'][2])
    report['time'].append(h['end']-h['start'])
# Out:
# Net time using :  454.25805020332336  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 0s 660us/step
# Slope Day1:1.0626723687742592
# Net time using :  760.1560835838318  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 0s 752us/step
# Slope Day1:0.9900842196544793
# Net time using :  306.44439148902893  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 0s 537us/step
# Slope Day1:1.0585482534073622
# Net time using :  445.79151368141174  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 0s 816us/step
# Slope Day1:1.0389103653620866
# Net time using :  628.6070606708527  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - 0s 414us/step
# Slope Day1:1.035293214428016
# Net time using :  539.6558933258057  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - 0s 781us/step
# Slope Day1:1.0424654096828305
# Net time using :  675.0612065792084  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - 0s 242us/step
# Slope Day1:1.0231199758871012
# Net time using :  274.84016847610474  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - 0s 241us/step
# Slope Day1:1.0492740203329536
# Net time using :  380.2439203262329  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - 0s 242us/step
# Slope Day1:1.0572559424989252
# Net time using :  711.1289367675781  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 1ms/step
# Slope Day1:1.048712009802214
# Net time using :  319.038626909256  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - 0s 489us/step
# Slope Day1:1.067926316323772
# Net time using :  513.6488873958588  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 1ms/step
# Slope Day1:1.0623210316927145
# Net time using :  428.611279964447  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 1ms/step
# Slope Day1:1.094910683121627
# Net time using :  201.76794123649597  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - 0s 431us/step
# Slope Day1:1.0786606385762416
# Net time using :  382.88337659835815  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - 0s 287us/step
# Slope Day1:1.0704076192424246
# Net time using :  459.03717517852783  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - 0s 242us/step
# Slope Day1:1.0415806084925152
# Net time using :  94.27865195274353  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 2ms/step
# Slope Day1:2.137427578090327
# Net time using :  580.5716495513916  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - 0s 537us/step
# Slope Day1:1.031369641798849
# Net time using :  529.9535491466522  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 1ms/step
# Slope Day1:1.0387656147274988
# Net time using :  642.6042141914368  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - 0s 539us/step
# Slope Day1:1.0178050341519413
# Net time using :  444.4556407928467  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - 0s 643us/step
# Slope Day1:1.0335481333369172
# Net time using :  842.9462230205536  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 3ms/step
# Slope Day1:1.038755728069282
# Net time using :  477.83046436309814  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 1ms/step
# Slope Day1:1.0763723010816575
# Net time using :  388.89030504226685  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - 0s 354us/step
# Slope Day1:1.0755470032496492
# Net time using :  745.0912330150604  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 1ms/step
# Slope Day1:1.0312088665553212
# Net time using :  490.21956610679626  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - 0s 385us/step
# Slope Day1:1.0165021100293425
# Net time using :  96.49410033226013  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 995us/step
# Slope Day1:2.2708389121616555
# Net time using :  351.10759806632996  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 2ms/step
# Slope Day1:1.06361779655948
# Net time using :  348.9892122745514  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - 0s 547us/step
# Slope Day1:1.0712762218329632
# Net time using :  231.38931035995483  secs.
# 520/520 [==============================] - ETA:  - ETA:  - ETA:  - 0s 252us/step
# Slope Day1:1.0800622881655622

# %% [markdown]
# ### 报告

# %%
pd.DataFrame(report).describe()
# Out:
#                 acc        time
# count  3.000000e+01   30.000000
# mean   9.615385e-03  458.199874
# std    1.764379e-18  187.953911
# min    9.615385e-03   94.278652
# 25%    9.615385e-03  349.518809
# 50%    9.615385e-03  450.024782
# 75%    9.615385e-03  570.342710
# max    9.615385e-03  842.946223
