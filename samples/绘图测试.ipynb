# %%
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

from LSTM_for_Stock.data_processor import DataLoader
from LSTM_for_Stock.model import Model
import seaborn as sns
# Out:
# Using TensorFlow backend.

# %%
dataloader = DataLoader('601398', '399300')

# %%
from LSTM_for_Stock import unit
window=30
days=5
X,Y=dataloader.get_train_data(window,days,False)
unit.plot(X,Y,window,figsize=(100,10))
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\GuQiang\\AppData\\Local\\conda\\conda\\envs\\finance35\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### 以下为测试代码

# %%
unit.plot_by_xl(X,Y,window,days,figsize=(100,10))
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\GuQiang\\AppData\\Local\\conda\\conda\\envs\\finance35\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# dataloader.data.iloc[0:100]['close']

# %%
# X,Y=dataloader.get_train_data(50,10,False)

# %%
# sns.lineplot(data=X[:100][:,0,0])
# sns.lineplot(data=Y[:100][:,0])

# %%
# import matplotlib.pyplot as plt
# def plot(X,Y,window):
#     sns.lineplot(data=X)
#     append=[None for p in range(window)]
#     plt.plot(append+list(Y))
    
# def plot1(X,Y,window):
#     sns.lineplot(data=X)
#     for i in range(len(Y)):
#         append=[None for p in range(window+i)]
#         plt.plot(append+list(Y[i]))
    
# plot1(X[:100][:,0,0],Y[:10],50)
