# %% [markdown]
# ## 测试环境
#
# * Intel Core i5-6500 3.2-GHz
# * 8.00GB

# %% [markdown]
# ## 测试内容

# %%
import jupyter_helper
from keras.backend import clear_session

import numpy as np
# Out:
# Using TensorFlow backend.

# %%
report={}
report['batch_size']=[]
report['window']=[]
report['time(secs)']=[]
# report['time/step(us)'].append('5')
report['loss']=[]
report['mean_absolute_error']=[]
report['acc']=[]
report['slope']=[]

# %% [markdown]
# ### 5 - 128

# %%
np.random.seed(1912)
h = jupyter_helper.do(
    batch_size=128,
    window=5,
    days=1,
    wrapper=jupyter_helper.wrapper_CCI(),
    norm=jupyter_helper.normalize_CCI())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 128)            79872
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 211,585
# Trainable params: 211,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
s=jupyter_helper.show_history(h)
# Out:
# Net time using :  53.97084355354309  secs.
# 508/508 [==============================] - ETA:  - 0s 105us/step
# Score:
# loss:0.0018095601667232049
# mean_absolute_error:0.03654218412290408
# acc:0.003937007874015748
# Slope Day1:1.0699189321456282

# %%
report['batch_size'].append(h['batch_size'])
report['window'].append(h['window'])
report['time(secs)'].append(h['end']-h['start'])
# report['time/step(us)'].append('5')
report['loss'].append(s['score'][0])
report['mean_absolute_error'].append(s['score'][1])
report['acc'].append(s['score'][2])
report['slope'].append(s['slope'][0])
clear_session()

# %% [markdown]
# ### 3 - 128

# %%
np.random.seed(1912)
h = jupyter_helper.do(
    batch_size=128,
    window=3,
    days=1,
    wrapper=jupyter_helper.wrapper_CCI(),
    norm=jupyter_helper.normalize_CCI())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 3, 128)            79872
# _________________________________________________________________
# dropout (Dropout)            (None, 3, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 211,585
# Trainable params: 211,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
s=jupyter_helper.show_history(h)
# Out:
# Net time using :  29.736969232559204  secs.
# 508/508 [==============================] - ETA:  - 0s 81us/step
# Score:
# loss:0.0012478124713305179
# mean_absolute_error:0.02945075624101744
# acc:0.003937007874015748
# Slope Day1:1.045777241413027

# %%
report['batch_size'].append(h['batch_size'])
report['window'].append(h['window'])
report['time(secs)'].append(h['end']-h['start'])
# report['time/step(us)'].append('5')
report['loss'].append(s['score'][0])
report['mean_absolute_error'].append(s['score'][1])
report['acc'].append(s['score'][2])
report['slope'].append(s['slope'][0])
clear_session()

# %%
report
# Out:
# {'acc': [0.003937007874015748, 0.003937007874015748],
#  'batch_size': [128, 128],
#  'loss': [0.0018095601667232049, 0.0012478124713305179],
#  'mean_absolute_error': [0.03654218412290408, 0.02945075624101744],
#  'slope': [1.0699189321456282, 1.045777241413027],
#  'time(secs)': [53.97084355354309, 29.736969232559204],
#  'window': [5, 3]}

# %% [markdown]
# ### 5 - 64

# %%
np.random.seed(1912)
h = jupyter_helper.do(
    batch_size=64,
    window=5,
    days=1,
    wrapper=jupyter_helper.wrapper_CCI(),
    norm=jupyter_helper.normalize_CCI())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 128)            79872
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 211,585
# Trainable params: 211,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
s=jupyter_helper.show_history(h)
# Out:
# Net time using :  94.35597014427185  secs.
# 508/508 [==============================] - ETA:  - 0s 98us/step
# Score:
# loss:0.0010680367681564485
# mean_absolute_error:0.025194709548565345
# acc:0.003937007874015748
# Slope Day1:1.0202099591979024

# %%
report['batch_size'].append(h['batch_size'])
report['window'].append(h['window'])
report['time(secs)'].append(h['end']-h['start'])
# report['time/step(us)'].append('5')
report['loss'].append(s['score'][0])
report['mean_absolute_error'].append(s['score'][1])
report['acc'].append(s['score'][2])
report['slope'].append(s['slope'][0])
clear_session()

# %% [markdown]
# ### 3 - 64

# %%
np.random.seed(1912)
h = jupyter_helper.do(
    batch_size=64,
    window=3,
    days=1,
    wrapper=jupyter_helper.wrapper_CCI(),
    norm=jupyter_helper.normalize_CCI())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 3, 128)            79872
# _________________________________________________________________
# dropout (Dropout)            (None, 3, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 211,585
# Trainable params: 211,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
s=jupyter_helper.show_history(h)
# Out:
# Net time using :  11.94296932220459  secs.
# 508/508 [==============================] - ETA:  - 0s 85us/step
# Score:
# loss:0.001412016929009944
# mean_absolute_error:0.03195349501049894
# acc:0.003937007874015748
# Slope Day1:0.9456781501235144

# %%
report['batch_size'].append(h['batch_size'])
report['window'].append(h['window'])
report['time(secs)'].append(h['end']-h['start'])
# report['time/step(us)'].append('5')
report['loss'].append(s['score'][0])
report['mean_absolute_error'].append(s['score'][1])
report['acc'].append(s['score'][2])
report['slope'].append(s['slope'][0])
clear_session()

# %% [markdown]
# ### 5 - 32

# %%
np.random.seed(1912)
h = jupyter_helper.do(
    batch_size=32,
    window=5,
    days=1,
    wrapper=jupyter_helper.wrapper_CCI(),
    norm=jupyter_helper.normalize_CCI())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 128)            79872
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 211,585
# Trainable params: 211,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
s=jupyter_helper.show_history(h)
# Out:
# Net time using :  73.21927309036255  secs.
# 508/508 [==============================] - ETA:  - ETA:  - 0s 147us/step
# Score:
# loss:0.0007771839787376912
# mean_absolute_error:0.02091880563617222
# acc:0.003937007874015748
# Slope Day1:0.9719348245573247

# %%
report['batch_size'].append(h['batch_size'])
report['window'].append(h['window'])
report['time(secs)'].append(h['end']-h['start'])
# report['time/step(us)'].append('5')
report['loss'].append(s['score'][0])
report['mean_absolute_error'].append(s['score'][1])
report['acc'].append(s['score'][2])
report['slope'].append(s['slope'][0])
clear_session()

# %% [markdown]
# ### 3 - 32

# %%
np.random.seed(1912)
h = jupyter_helper.do(
    batch_size=32,
    window=3,
    days=1,
    wrapper=jupyter_helper.wrapper_CCI(),
    norm=jupyter_helper.normalize_CCI())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 3, 128)            79872
# _________________________________________________________________
# dropout (Dropout)            (None, 3, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 211,585
# Trainable params: 211,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
s=jupyter_helper.show_history(h)
# Out:
# Net time using :  50.460999965667725  secs.
# 508/508 [==============================] - ETA:  - 0s 88us/step
# Score:
# loss:0.0006659926164172971
# mean_absolute_error:0.018033558114131137
# acc:0.003937007874015748
# Slope Day1:1.0414195013427765

# %%
report['batch_size'].append(h['batch_size'])
report['window'].append(h['window'])
report['time(secs)'].append(h['end']-h['start'])
# report['time/step(us)'].append('5')
report['loss'].append(s['score'][0])
report['mean_absolute_error'].append(s['score'][1])
report['acc'].append(s['score'][2])
report['slope'].append(s['slope'][0])
clear_session()

# %% [markdown]
# ### 5 - 16

# %%
np.random.seed(1912)
h = jupyter_helper.do(
    batch_size=16,
    window=5,
    days=1,
    wrapper=jupyter_helper.wrapper_CCI(),
    norm=jupyter_helper.normalize_CCI())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 128)            79872
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 211,585
# Trainable params: 211,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
s=jupyter_helper.show_history(h)
# Out:
# Net time using :  137.93746829032898  secs.
# 508/508 [==============================] - ETA:  - 0s 107us/step
# Score:
# loss:0.0006924884860847497
# mean_absolute_error:0.019245124818009184
# acc:0.003937007874015748
# Slope Day1:0.9620849801273603

# %%
report['batch_size'].append(h['batch_size'])
report['window'].append(h['window'])
report['time(secs)'].append(h['end']-h['start'])
# report['time/step(us)'].append('5')
report['loss'].append(s['score'][0])
report['mean_absolute_error'].append(s['score'][1])
report['acc'].append(s['score'][2])
report['slope'].append(s['slope'][0])
clear_session()

# %% [markdown]
# ### 3 - 16

# %%
np.random.seed(1912)
h = jupyter_helper.do(
    batch_size=16,
    window=3,
    days=1,
    wrapper=jupyter_helper.wrapper_CCI(),
    norm=jupyter_helper.normalize_CCI())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 3, 128)            79872
# _________________________________________________________________
# dropout (Dropout)            (None, 3, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 211,585
# Trainable params: 211,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
s=jupyter_helper.show_history(h)
# Out:
# Net time using :  38.621466875076294  secs.
# 508/508 [==============================] - ETA:  - 0s 86us/step
# Score:
# loss:0.0006648998450410853
# mean_absolute_error:0.01824303324825651
# acc:0.003937007874015748
# Slope Day1:1.0301817649867318

# %%
report['batch_size'].append(h['batch_size'])
report['window'].append(h['window'])
report['time(secs)'].append(h['end']-h['start'])
# report['time/step(us)'].append('5')
report['loss'].append(s['score'][0])
report['mean_absolute_error'].append(s['score'][1])
report['acc'].append(s['score'][2])
report['slope'].append(s['slope'][0])
clear_session()

# %% [markdown]
# ### 5 - 8

# %%
np.random.seed(1912)
h = jupyter_helper.do(
    batch_size=8,
    window=5,
    days=1,
    wrapper=jupyter_helper.wrapper_CCI(),
    norm=jupyter_helper.normalize_CCI())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 128)            79872
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 211,585
# Trainable params: 211,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
s=jupyter_helper.show_history(h)
# Out:
# Net time using :  81.23099994659424  secs.
# 508/508 [==============================] - ETA:  - ETA:  - 0s 122us/step
# Score:
# loss:0.0006965379366801509
# mean_absolute_error:0.018879657677250115
# acc:0.003937007874015748
# Slope Day1:0.9599662737674326

# %%
report['batch_size'].append(h['batch_size'])
report['window'].append(h['window'])
report['time(secs)'].append(h['end']-h['start'])
# report['time/step(us)'].append('5')
report['loss'].append(s['score'][0])
report['mean_absolute_error'].append(s['score'][1])
report['acc'].append(s['score'][2])
report['slope'].append(s['slope'][0])
clear_session()

# %% [markdown]
# ### 3 - 8

# %%
np.random.seed(1912)
h = jupyter_helper.do(
    batch_size=8,
    window=3,
    days=1,
    wrapper=jupyter_helper.wrapper_CCI(),
    norm=jupyter_helper.normalize_CCI())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 3, 128)            79872
# _________________________________________________________________
# dropout (Dropout)            (None, 3, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 211,585
# Trainable params: 211,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
s=jupyter_helper.show_history(h)
# Out:
# Net time using :  120.93246912956238  secs.
# 508/508 [==============================] - ETA:  - 0s 85us/step
# Score:
# loss:0.000681961118426966
# mean_absolute_error:0.018458722731259865
# acc:0.003937007874015748
# Slope Day1:1.0290991703262475

# %%
report['batch_size'].append(h['batch_size'])
report['window'].append(h['window'])
report['time(secs)'].append(h['end']-h['start'])
# report['time/step(us)'].append('5')
report['loss'].append(s['score'][0])
report['mean_absolute_error'].append(s['score'][1])
report['acc'].append(s['score'][2])
report['slope'].append(s['slope'][0])
clear_session()

# %% [markdown]
# ### 5 - 4

# %%
np.random.seed(1912)
h = jupyter_helper.do(
    batch_size=4,
    window=5,
    days=1,
    wrapper=jupyter_helper.wrapper_CCI(),
    norm=jupyter_helper.normalize_CCI())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 128)            79872
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 211,585
# Trainable params: 211,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
s=jupyter_helper.show_history(h)
# Out:
# Net time using :  289.38450264930725  secs.
# 508/508 [==============================] - ETA:  - 0s 110us/step
# Score:
# loss:0.0007017503295911432
# mean_absolute_error:0.01912520402734439
# acc:0.003937007874015748
# Slope Day1:0.9791003814880598

# %%
report['batch_size'].append(h['batch_size'])
report['window'].append(h['window'])
report['time(secs)'].append(h['end']-h['start'])
# report['time/step(us)'].append('5')
report['loss'].append(s['score'][0])
report['mean_absolute_error'].append(s['score'][1])
report['acc'].append(s['score'][2])
report['slope'].append(s['slope'][0])
clear_session()

# %% [markdown]
# ### 3 - 4

# %%
np.random.seed(1912)
h = jupyter_helper.do(
    batch_size=4,
    window=3,
    days=1,
    wrapper=jupyter_helper.wrapper_CCI(),
    norm=jupyter_helper.normalize_CCI())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 3, 128)            79872
# _________________________________________________________________
# dropout (Dropout)            (None, 3, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 211,585
# Trainable params: 211,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
s=jupyter_helper.show_history(h)
# Out:
# Net time using :  194.50050020217896  secs.
# 508/508 [==============================] - ETA:  - 0s 81us/step
# Score:
# loss:0.000676905577974834
# mean_absolute_error:0.018197529545919165
# acc:0.003937007874015748
# Slope Day1:1.009872327279006

# %%
report['batch_size'].append(h['batch_size'])
report['window'].append(h['window'])
report['time(secs)'].append(h['end']-h['start'])
# report['time/step(us)'].append('5')
report['loss'].append(s['score'][0])
report['mean_absolute_error'].append(s['score'][1])
report['acc'].append(s['score'][2])
report['slope'].append(s['slope'][0])
clear_session()

# %% [markdown]
# ### 5 - 2

# %%
np.random.seed(1912)
h = jupyter_helper.do(
    batch_size=2,
    window=5,
    days=1,
    wrapper=jupyter_helper.wrapper_CCI(),
    norm=jupyter_helper.normalize_CCI())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 128)            79872
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 211,585
# Trainable params: 211,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
s=jupyter_helper.show_history(h)
# Out:
# Net time using :  288.9074673652649  secs.
# 508/508 [==============================] - ETA:  - ETA:  - 0s 156us/step
# Score:
# loss:0.0007372673524829639
# mean_absolute_error:0.019575055189958706
# acc:0.003937007874015748
# Slope Day1:0.994538061976366

# %%
report['batch_size'].append(h['batch_size'])
report['window'].append(h['window'])
report['time(secs)'].append(h['end']-h['start'])
# report['time/step(us)'].append('5')
report['loss'].append(s['score'][0])
report['mean_absolute_error'].append(s['score'][1])
report['acc'].append(s['score'][2])
report['slope'].append(s['slope'][0])
clear_session()

# %% [markdown]
# ### 3 - 2

# %%
np.random.seed(1912)
h = jupyter_helper.do(
    batch_size=2,
    window=3,
    days=1,
    wrapper=jupyter_helper.wrapper_CCI(),
    norm=jupyter_helper.normalize_CCI())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 3, 128)            79872
# _________________________________________________________________
# dropout (Dropout)            (None, 3, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 211,585
# Trainable params: 211,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
s=jupyter_helper.show_history(h)
# Out:
# Net time using :  209.88750004768372  secs.
# 508/508 [==============================] - ETA:  - ETA:  - 0s 146us/step
# Score:
# loss:0.0007149412548334491
# mean_absolute_error:0.01895859999596838
# acc:0.003937007874015748
# Slope Day1:1.126552479080546

# %%
report['batch_size'].append(h['batch_size'])
report['window'].append(h['window'])
report['time(secs)'].append(h['end']-h['start'])
# report['time/step(us)'].append('5')
report['loss'].append(s['score'][0])
report['mean_absolute_error'].append(s['score'][1])
report['acc'].append(s['score'][2])
report['slope'].append(s['slope'][0])
clear_session()

# %% [markdown]
# ## 统计报告

# %%
import pandas as pd
report_df=pd.DataFrame(report).set_index(['batch_size','window'])
report_df['slope1']=abs(report_df['slope']-1)
report_df.sort_values('slope1')
# Out:
#                         acc      loss  mean_absolute_error     slope  \
# batch_size window
# 2          5       0.003937  0.000737             0.019575  0.994538
# 4          3       0.003937  0.000677             0.018198  1.009872
# 64         5       0.003937  0.001068             0.025195  1.020210
# 4          5       0.003937  0.000702             0.019125  0.979100
# 32         5       0.003937  0.000777             0.020919  0.971935
# 8          3       0.003937  0.000682             0.018459  1.029099
# 16         3       0.003937  0.000665             0.018243  1.030182
#            5       0.003937  0.000692             0.019245  0.962085
# 8          5       0.003937  0.000697             0.018880  0.959966
# 32         3       0.003937  0.000666             0.018034  1.041420
# 128        3       0.003937  0.001248             0.029451  1.045777
# 64         3       0.003937  0.001412             0.031953  0.945678
# 128        5       0.003937  0.001810             0.036542  1.069919
# 2          3       0.003937  0.000715             0.018959  1.126552
#
#                    time(secs)    slope1
# batch_size window
# 2          5       288.907467  0.005462
# 4          3       194.500500  0.009872
# 64         5        94.355970  0.020210
# 4          5       289.384503  0.020900
# 32         5        73.219273  0.028065
# 8          3       120.932469  0.029099
# 16         3        38.621467  0.030182
#            5       137.937468  0.037915
# 8          5        81.231000  0.040034
# 32         3        50.461000  0.041420
# 128        3        29.736969  0.045777
# 64         3        11.942969  0.054322
# 128        5        53.970844  0.069919
# 2          3       209.887500  0.126552
