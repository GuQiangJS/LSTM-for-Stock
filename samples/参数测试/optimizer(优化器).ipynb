# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import sys
sys.path.append(os.path.dirname(os.getcwd()))
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))
import jupyter_helper
from keras.backend import clear_session
import pandas as pd
import numpy as np
from LSTM_for_Stock.data_processor import Wrapper_default
from LSTM_for_Stock.data_processor import Normalize
from LSTM_for_Stock.loss import root_mean_squared_error
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 测试环境

# %%
jupyter_helper.print_system_info()
# Out:
# OS Name: b'Microsoft Windows Server 2012 R2 Standard'
# OS Version: 6.3.9600 9600
# CPU: Intel(R) Core(TM) i3-2120 CPU @ 3.30GHz
# RAM: 11.941967010498047 GB
# Graphics Card: NVIDIA GeForce GTX 750 Ti

# %%
report={}
report['acc']=[]
report['mae']=[]
report['loss']=[]
report['time']=[]
report['utils']=[]
report['window']=[]
report['days']=[]
report['batch_size']=[]
report['act']=[]
report['opt']=[]

# %%
times = 10
batch_size = 256
utils = 64
act = None
opts = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']
for opt in opts:
    for i in range(times):
        print('{0}/{1}[{2}]'.format(i+1, times, opt))
        ls = [{'type': 'lstm', 'units': utils},
              {'type': 'dense', 'activation': act}]
        complie = {'loss': root_mean_squared_error,
                   'optimizer': opt, 'metrics': ["mae", "acc"]}
        h = jupyter_helper.do(layers=ls, summary=False, batch_size=batch_size)
        s = jupyter_helper.show_history(h, show_plt=False)
        clear_session()
        report['window'].append(h['window'])
        report['days'].append(h['days'])
        report['batch_size'].append(h['batch_size'])
        report['acc'].append(s['score'][2])
        report['mae'].append(s['score'][1])
        report['loss'].append(s['score'][0])
        report['time'].append(h['end']-h['start'])
        report['utils'].append(64)
        report['act'].append(act)
        report['opt'].append(opt)
# Out:
# 1/10[None]
# Net time using :  30.424559831619263  secs.
# 489/489 [==============================] - ETA:  - 0s 65us/step
# Score:
#  loss:0.030284685899783496
#  mean_absolute_error:0.023989209970021297
#  acc:0.002044989775051125
# 2/10[None]
# Net time using :  30.81656527519226  secs.
# 489/489 [==============================] - ETA:  - 0s 80us/step
# Score:
#  loss:0.030299035577076833
#  mean_absolute_error:0.02406856812277698
#  acc:0.002044989775051125
# 3/10[None]
# Net time using :  31.571581840515137  secs.
# 489/489 [==============================] - ETA:  - 0s 63us/step
# Score:
#  loss:0.02982155309803403
#  mean_absolute_error:0.023746040564007555
#  acc:0.002044989775051125
# 4/10[None]
# Net time using :  30.995655298233032  secs.
# 489/489 [==============================] - ETA:  - 0s 53us/step
# Score:
#  loss:0.030687793319881085
#  mean_absolute_error:0.02450813765967063
#  acc:0.002044989775051125
# 5/10[None]
# Net time using :  31.13375425338745  secs.
# 489/489 [==============================] - ETA:  - 0s 51us/step
# Score:
#  loss:0.030278432291526734
#  mean_absolute_error:0.024070255968773047
#  acc:0.002044989775051125
# 6/10[None]
# Net time using :  32.1999135017395  secs.
# 489/489 [==============================] - ETA:  - 0s 59us/step
# Score:
#  loss:0.030700525566021358
#  mean_absolute_error:0.024647702350603047
#  acc:0.002044989775051125
# 7/10[None]
# Net time using :  32.29556941986084  secs.
# 489/489 [==============================] - ETA:  - 0s 63us/step
# Score:
#  loss:0.030057810921153408
#  mean_absolute_error:0.023821906938935593
#  acc:0.002044989775051125
# 8/10[None]
# Net time using :  31.894718408584595  secs.
# 489/489 [==============================] - ETA:  - 0s 55us/step
# Score:
#  loss:0.030887325056247673
#  mean_absolute_error:0.02463122526972206
#  acc:0.002044989775051125
# 9/10[None]
# Net time using :  31.938666105270386  secs.
# 489/489 [==============================] - ETA:  - 0s 51us/step
# Score:
#  loss:0.02947374239777251
#  mean_absolute_error:0.02319508058862696
#  acc:0.002044989775051125
# 10/10[None]
# Net time using :  31.748684644699097  secs.
# 489/489 [==============================] - ETA:  - 0s 55us/step
# Score:
#  loss:0.02985981620223488
#  mean_absolute_error:0.023848121646784078
#  acc:0.002044989775051125
# 1/10[None]
# Net time using :  31.80731701850891  secs.
# 489/489 [==============================] - ETA:  - 0s 51us/step
# Score:
#  loss:0.029878053307563737
#  mean_absolute_error:0.023758147384186707
#  acc:0.002044989775051125
# 2/10[None]
# Net time using :  31.964792728424072  secs.
# 489/489 [==============================] - ETA:  - 0s 74us/step
# Score:
#  loss:0.029942266288801936
#  mean_absolute_error:0.023898379801027856
#  acc:0.002044989775051125
# 3/10[None]
# Net time using :  31.956284761428833  secs.
# 489/489 [==============================] - ETA:  - 0s 55us/step
# Score:
#  loss:0.029601112091894775
#  mean_absolute_error:0.02343502183252439
#  acc:0.002044989775051125
# 4/10[None]
# Net time using :  31.689906358718872  secs.
# 489/489 [==============================] - ETA:  - 0s 45us/step
# Score:
#  loss:0.029420534720175837
#  mean_absolute_error:0.023336557020073288
#  acc:0.002044989775051125
# 5/10[None]
# Net time using :  31.72749376296997  secs.
# 489/489 [==============================] - ETA:  - 0s 51us/step
# Score:
#  loss:0.029584280605635515
#  mean_absolute_error:0.02340686309069456
#  acc:0.002044989775051125
# 6/10[None]
# Net time using :  31.900471448898315  secs.
# 489/489 [==============================] - ETA:  - 0s 47us/step
# Score:
#  loss:0.030349229856685627
#  mean_absolute_error:0.024204481358817018
#  acc:0.002044989775051125
# 7/10[None]
# Net time using :  31.883392095565796  secs.
# 489/489 [==============================] - ETA:  - 0s 59us/step
# Score:
#  loss:0.030389067082683
#  mean_absolute_error:0.02412492682079352
#  acc:0.002044989775051125
# 8/10[None]
# Net time using :  31.89886736869812  secs.
# 489/489 [==============================] - ETA:  - 0s 51us/step
# Score:
#  loss:0.030254322513633223
#  mean_absolute_error:0.024069230614995663
#  acc:0.002044989775051125
# 9/10[None]
# Net time using :  31.295222520828247  secs.
# 489/489 [==============================] - ETA:  - 0s 59us/step
# Score:
#  loss:0.030160921738161144
#  mean_absolute_error:0.024082425429441934
#  acc:0.002044989775051125
# 10/10[None]
# Net time using :  31.76822519302368  secs.
# 489/489 [==============================] - ETA:  - 0s 57us/step
# Score:
#  loss:0.029840461506007394
#  mean_absolute_error:0.02366150900005441
#  acc:0.002044989775051125
# 1/10[None]
# Net time using :  31.911761045455933  secs.
# 489/489 [==============================] - ETA:  - 0s 47us/step
# Score:
#  loss:0.029697087648608445
#  mean_absolute_error:0.023590796670908822
#  acc:0.002044989775051125
# 2/10[None]
# Net time using :  31.44987654685974  secs.
# 489/489 [==============================] - ETA:  - 0s 49us/step
# Score:
#  loss:0.030568345249887625
#  mean_absolute_error:0.024445125181799286
#  acc:0.002044989775051125
# 3/10[None]
# Net time using :  31.4131920337677  secs.
# 489/489 [==============================] - ETA:  - 0s 43us/step
# Score:
#  loss:0.029364477812573467
#  mean_absolute_error:0.023176106218637135
#  acc:0.002044989775051125
# 4/10[None]
# Net time using :  30.840821504592896  secs.
# 489/489 [==============================] - ETA:  - 0s 43us/step
# Score:
#  loss:0.029538288872483318
#  mean_absolute_error:0.023606942117153258
#  acc:0.002044989775051125
# 5/10[None]
# Net time using :  31.193641662597656  secs.
# 489/489 [==============================] - ETA:  - 0s 55us/step
# Score:
#  loss:0.03057792900103489
#  mean_absolute_error:0.024335932756006595
#  acc:0.002044989775051125
# 6/10[None]
# Net time using :  31.698843479156494  secs.
# 489/489 [==============================] - ETA:  - 0s 49us/step
# Score:
#  loss:0.029825392371550172
#  mean_absolute_error:0.02374901177632053
#  acc:0.002044989775051125
# 7/10[None]
# Net time using :  31.67012310028076  secs.
# 489/489 [==============================] - ETA:  - 0s 53us/step
# Score:
#  loss:0.030765915834221128
#  mean_absolute_error:0.0246388905039838
#  acc:0.002044989775051125
# 8/10[None]
# Net time using :  31.47775101661682  secs.
# 489/489 [==============================] - ETA:  - 0s 55us/step
# Score:
#  loss:0.0299210573845602
#  mean_absolute_error:0.02363811032598979
#  acc:0.002044989775051125
# 9/10[None]
# Net time using :  31.812447786331177  secs.
# 489/489 [==============================] - ETA:  - 0s 43us/step
# Score:
#  loss:0.030373197445047902
#  mean_absolute_error:0.024219846539580262
#  acc:0.002044989775051125
# 10/10[None]
# Net time using :  31.603155612945557  secs.
# 489/489 [==============================] - ETA:  - 0s 49us/step
# Score:
#  loss:0.030481279517213505
#  mean_absolute_error:0.024305398604529765
#  acc:0.002044989775051125
# 1/10[None]
# Net time using :  31.514277458190918  secs.
# 489/489 [==============================] - ETA:  - 0s 49us/step
# Score:
#  loss:0.030207190053168007
#  mean_absolute_error:0.024086750739069317
#  acc:0.002044989775051125
# 2/10[None]
# Net time using :  32.841670751571655  secs.
# 489/489 [==============================] - ETA:  - 0s 51us/step
# Score:
#  loss:0.02981675815804726
#  mean_absolute_error:0.023620773548667904
#  acc:0.002044989775051125
# 3/10[None]
# Net time using :  31.13165307044983  secs.
# 489/489 [==============================] - ETA:  - 0s 47us/step
# Score:
#  loss:0.029942853060114846
#  mean_absolute_error:0.02393854701994387
#  acc:0.002044989775051125
# 4/10[None]
# Net time using :  31.701744079589844  secs.
# 489/489 [==============================] - ETA:  - 0s 51us/step
# Score:
#  loss:0.030073795018142474
#  mean_absolute_error:0.0238895546683017
#  acc:0.002044989775051125
# 5/10[None]
# Net time using :  31.54506206512451  secs.
# 489/489 [==============================] - ETA:  - 0s 47us/step
# Score:
#  loss:0.03045877057807577
#  mean_absolute_error:0.024299038341745034
#  acc:0.002044989775051125
# 6/10[None]
# Net time using :  31.765475511550903  secs.
# 489/489 [==============================] - ETA:  - 0s 51us/step
# Score:
#  loss:0.02986789857759188
#  mean_absolute_error:0.02376010568321117
#  acc:0.002044989775051125
# 7/10[None]
# Net time using :  32.019538164138794  secs.
# 489/489 [==============================] - ETA:  - 0s 45us/step
# Score:
#  loss:0.0295452671792122
#  mean_absolute_error:0.02335065968547984
#  acc:0.002044989775051125
# 8/10[None]
# Net time using :  31.644608974456787  secs.
# 489/489 [==============================] - ETA:  - 0s 51us/step
# Score:
#  loss:0.02983332302322295
#  mean_absolute_error:0.023583092690580707
#  acc:0.002044989775051125
# 9/10[None]
# Net time using :  32.07715034484863  secs.
# 489/489 [==============================] - ETA:  - 0s 49us/step
# Score:
#  loss:0.030423268896731373
#  mean_absolute_error:0.02437139117751263
#  acc:0.002044989775051125
# 10/10[None]
# Net time using :  31.499756813049316  secs.
# 489/489 [==============================] - ETA:  - 0s 55us/step
# Score:
#  loss:0.03005708039477315
#  mean_absolute_error:0.023821275521275456
#  acc:0.002044989775051125
# 1/10[None]
# Net time using :  31.761777877807617  secs.
# 489/489 [==============================] - ETA:  - 0s 63us/step
# Score:
#  loss:0.02958610177360064
#  mean_absolute_error:0.02333926714971997
#  acc:0.002044989775051125
# 2/10[None]
# Net time using :  32.01366305351257  secs.
# 489/489 [==============================] - ETA:  - 0s 55us/step
# Score:
#  loss:0.030516457635383666
#  mean_absolute_error:0.02438665522311972
#  acc:0.002044989775051125
# 3/10[None]
# Net time using :  31.514564514160156  secs.
# 489/489 [==============================] - ETA:  - 0s 55us/step
# Score:
#  loss:0.03049406866735354
#  mean_absolute_error:0.024440749786443748
#  acc:0.002044989775051125
# 4/10[None]
# Net time using :  31.73537039756775  secs.
# 489/489 [==============================] - ETA:  - 0s 55us/step
# Score:
#  loss:0.029605754912051932
#  mean_absolute_error:0.02354327324541678
#  acc:0.002044989775051125
# 5/10[None]
# Net time using :  32.119030237197876  secs.
# 489/489 [==============================] - ETA:  - 0s 51us/step
# Score:
#  loss:0.02969544473083229
#  mean_absolute_error:0.023531539910349134
#  acc:0.002044989775051125
# 6/10[None]
# Net time using :  31.061319828033447  secs.
# 489/489 [==============================] - ETA:  - 0s 53us/step
# Score:
#  loss:0.03044129592692194
#  mean_absolute_error:0.024433499224986766
#  acc:0.002044989775051125
# 7/10[None]
# Net time using :  31.757715702056885  secs.
# 489/489 [==============================] - ETA:  - 0s 57us/step
# Score:
#  loss:0.030583575162236677
#  mean_absolute_error:0.02442694586798823
#  acc:0.002044989775051125
# 8/10[None]
# Net time using :  31.694032669067383  secs.
# 489/489 [==============================] - ETA:  - 0s 47us/step
# Score:
#  loss:0.03091282529303145
#  mean_absolute_error:0.024716660517490715
#  acc:0.002044989775051125
# 9/10[None]
# Net time using :  31.18349003791809  secs.
# 489/489 [==============================] - ETA:  - 0s 53us/step
# Score:
#  loss:0.02947427244792199
#  mean_absolute_error:0.02334214305478493
#  acc:0.002044989775051125
# 10/10[None]
# Net time using :  31.574871063232422  secs.
# 489/489 [==============================] - ETA:  - 0s 47us/step
# Score:
#  loss:0.03049289404675517
#  mean_absolute_error:0.02446832257972417
#  acc:0.002044989775051125
# 1/10[None]
# Net time using :  31.25079321861267  secs.
# 489/489 [==============================] - ETA:  - 0s 53us/step
# Score:
#  loss:0.029805201827596058
#  mean_absolute_error:0.023785497273312757
#  acc:0.002044989775051125
# 2/10[None]
# Net time using :  31.54171085357666  secs.
# 489/489 [==============================] - ETA:  - 0s 49us/step
# Score:
#  loss:0.02944971441628377
#  mean_absolute_error:0.02334228262366205
#  acc:0.002044989775051125
# 3/10[None]
# Net time using :  32.28901672363281  secs.
# 489/489 [==============================] - ETA:  - 0s 59us/step
# Score:
#  loss:0.03046513516798707
#  mean_absolute_error:0.024277157944404274
#  acc:0.002044989775051125
# 4/10[None]
# Net time using :  31.286617517471313  secs.
# 489/489 [==============================] - ETA:  - 0s 55us/step
# Score:
#  loss:0.02976769995866134
#  mean_absolute_error:0.023459037023087954
#  acc:0.002044989775051125
# 5/10[None]
# Net time using :  31.689475536346436  secs.
# 489/489 [==============================] - ETA:  - 0s 51us/step
# Score:
#  loss:0.0300144868120094
#  mean_absolute_error:0.023813822525715293
#  acc:0.002044989775051125
# 6/10[None]
# Net time using :  31.534471035003662  secs.
# 489/489 [==============================] - ETA:  - 0s 53us/step
# Score:
#  loss:0.03043673064841571
#  mean_absolute_error:0.024284555380573544
#  acc:0.002044989775051125
# 7/10[None]
# Net time using :  31.915240049362183  secs.
# 489/489 [==============================] - ETA:  - 0s 49us/step
# Score:
#  loss:0.030879288492819526
#  mean_absolute_error:0.02469502551698246
#  acc:0.002044989775051125
# 8/10[None]
# Net time using :  31.907181978225708  secs.
# 489/489 [==============================] - ETA:  - 0s 49us/step
# Score:
#  loss:0.02991284938159652
#  mean_absolute_error:0.023825237828407796
#  acc:0.002044989775051125
# 9/10[None]
# Net time using :  31.16198468208313  secs.
# 489/489 [==============================] - ETA:  - 0s 43us/step
# Score:
#  loss:0.029865546220559282
#  mean_absolute_error:0.023810796439647675
#  acc:0.002044989775051125
# 10/10[None]
# Net time using :  31.573200702667236  secs.
# 489/489 [==============================] - ETA:  - 0s 45us/step
# Score:
#  loss:0.030228324348758336
#  mean_absolute_error:0.02418706325741755
#  acc:0.002044989775051125
# 1/10[None]
# Net time using :  31.307239055633545  secs.
# 489/489 [==============================] - ETA:  - 0s 57us/step
# Score:
#  loss:0.030194089342297222
#  mean_absolute_error:0.02414241475043609
#  acc:0.002044989775051125
# 2/10[None]
# Net time using :  31.433752059936523  secs.
# 489/489 [==============================] - ETA:  - 0s 61us/step
# Score:
#  loss:0.02988066661013538
#  mean_absolute_error:0.023715163529650564
#  acc:0.002044989775051125
# 3/10[None]
# Net time using :  31.9303081035614  secs.
# 489/489 [==============================] - ETA:  - 0s 45us/step
# Score:
#  loss:0.030209136761130732
#  mean_absolute_error:0.024041632441746678
#  acc:0.002044989775051125
# 4/10[None]
# Net time using :  31.64304518699646  secs.
# 489/489 [==============================] - ETA:  - 0s 45us/step
# Score:
#  loss:0.02979797327125365
#  mean_absolute_error:0.023439552036927276
#  acc:0.002044989775051125
# 5/10[None]
# Net time using :  31.446149110794067  secs.
# 489/489 [==============================] - ETA:  - 0s 47us/step
# Score:
#  loss:0.02980647265819684
#  mean_absolute_error:0.023817305912117042
#  acc:0.002044989775051125
# 6/10[None]
# Net time using :  31.50319528579712  secs.
# 489/489 [==============================] - ETA:  - 0s 49us/step
# Score:
#  loss:0.030045634409858406
#  mean_absolute_error:0.02393804214026299
#  acc:0.002044989775051125
# 7/10[None]
# Net time using :  31.552724361419678  secs.
# 489/489 [==============================] - ETA:  - 0s 47us/step
# Score:
#  loss:0.029693335656587088
#  mean_absolute_error:0.023478902053613603
#  acc:0.002044989775051125
# 8/10[None]
# Net time using :  31.922983407974243  secs.
# 489/489 [==============================] - ETA:  - 0s 47us/step
# Score:
#  loss:0.030342249957757007
#  mean_absolute_error:0.024140794207256264
#  acc:0.002044989775051125
# 9/10[None]
# Net time using :  31.313984632492065  secs.
# 489/489 [==============================] - ETA:  - 0s 45us/step
# Score:
#  loss:0.02998321042500878
#  mean_absolute_error:0.023834477051147898
#  acc:0.002044989775051125
# 10/10[None]
# Net time using :  32.79384183883667  secs.
# 489/489 [==============================] - ETA:  - 0s 53us/step
# Score:
#  loss:0.030221332237886263
#  mean_absolute_error:0.024088464867788345
#  acc:0.002044989775051125

# %% [markdown]
# ### 报告

# %%
pd.DataFrame(report)[['time','acc','opt']].groupby('opt').describe()
# Out:
#            acc                                                         \
#          count      mean  std       min       25%       50%       75%
# opt
# Adadelta  10.0  0.002045  0.0  0.002045  0.002045  0.002045  0.002045